# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data
# data = pd.read_csv('C:/Users/Administrator.MMCY/Desktop/10a/Bati-Bank-W6/data .csv')  # Replace with your file path
data = pd.read_csv("../src/data/data.csv")

# %%
# Display the first few rows of the dataset
print("First 5 rows of the dataset:")
data.head()
# Out:
# First 5 rows of the dataset:
#          TransactionId         BatchId       AccountId       SubscriptionId  \
# 0  TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1  TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2  TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3    TransactionId_380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4  TransactionId_28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
#
#         CustomerId CurrencyCode  CountryCode    ProviderId     ProductId  \
# 0  CustomerId_4406          UGX          256  ProviderId_6  ProductId_10
# 1  CustomerId_4406          UGX          256  ProviderId_4   ProductId_6
# 2  CustomerId_4683          UGX          256  ProviderId_6   ProductId_1
# 3   CustomerId_988          UGX          256  ProviderId_1  ProductId_21
# 4   CustomerId_988          UGX          256  ProviderId_4   ProductId_6
#
# ...

# %%
# Basic information about the dataset
print("\nDataset Information:")
data.info()
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95662 entries, 0 to 95661
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   TransactionId         95662 non-null  object
#  1   BatchId               95662 non-null  object
#  2   AccountId             95662 non-null  object
#  3   SubscriptionId        95662 non-null  object
#  4   CustomerId            95662 non-null  object
#  5   CurrencyCode          95662 non-null  object
#  6   CountryCode           95662 non-null  int64
#  7   ProviderId            95662 non-null  object
#  8   ProductId             95662 non-null  object
#  9   ProductCategory       95662 non-null  object
#  10  ChannelId             95662 non-null  object
#  11  Amount                95662 non-null  float64
#  12  Value                 95662 non-null  int64
#  13  TransactionStartTime  95662 non-null  object
# ...

# %%
# Summary statistics for numerical columns
print("\nSummary Statistics for Numerical Columns:")
data.describe()
# Out:
# Summary Statistics for Numerical Columns:
#        CountryCode        Amount         Value  PricingStrategy   FraudResult
# count      95662.0  9.566200e+04  9.566200e+04     95662.000000  95662.000000
# mean         256.0  6.717846e+03  9.900584e+03         2.255974      0.002018
# std            0.0  1.233068e+05  1.231221e+05         0.732924      0.044872
# min          256.0 -1.000000e+06  2.000000e+00         0.000000      0.000000
# 25%          256.0 -5.000000e+01  2.750000e+02         2.000000      0.000000
# 50%          256.0  1.000000e+03  1.000000e+03         2.000000      0.000000
# 75%          256.0  2.800000e+03  5.000000e+03         2.000000      0.000000
# max          256.0  9.880000e+06  9.880000e+06         4.000000      1.000000

# %%
# Check for missing values
print("\nMissing Values in Each Column:")
print(data.isnull().sum())
# Out:
# Missing Values in Each Column:
# TransactionId           0
# BatchId                 0
# AccountId               0
# SubscriptionId          0
# CustomerId              0
# CurrencyCode            0
# CountryCode             0
# ProviderId              0
# ProductId               0
# ProductCategory         0
# ChannelId               0
# Amount                  0
# Value                   0
# TransactionStartTime    0
# PricingStrategy         0
# FraudResult             0
# dtype: int64

# %%
# Distribution of numerical features
numerical_features = ['Amount', 'Value']
print("\nDistribution of Numerical Features:")
data[numerical_features].hist(bins=30, figsize=(10, 5))
plt.suptitle("Distribution of Numerical Features")
plt.show()
# Out:
# Distribution of Numerical Features:

# %%
# Distribution of categorical features
categorical_features = ['ProductCategory', 'ChannelId', 'FraudResult']
print("\nDistribution of Categorical Features:")
for feature in categorical_features:
    plt.figure(figsize=(8, 4))
    sns.countplot(data=data, x=feature, palette='viridis')
    plt.title(f"Distribution of {feature}")
    plt.xticks(rotation=45)
    plt.show()
# Out:
# Distribution of Categorical Features:
# C:\Users\Administrator.MMCY\AppData\Local\Temp\ipykernel_13196\2877152763.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x=feature, palette='viridis')
# C:\Users\Administrator.MMCY\AppData\Local\Temp\ipykernel_13196\2877152763.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x=feature, palette='viridis')
# C:\Users\Administrator.MMCY\AppData\Local\Temp\ipykernel_13196\2877152763.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
# Correlation analysis for numerical features
print("\nCorrelation Matrix for Numerical Features:")
corr_matrix = data[numerical_features].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Matrix")
plt.show()
# Out:
# Correlation Matrix for Numerical Features:

# %%
# Outlier detection using box plots
print("\nOutlier Detection for Numerical Features:")
plt.figure(figsize=(10, 5))
sns.boxplot(data=data[numerical_features], palette='Set2')
plt.title("Box Plot for Numerical Features")
plt.show()
# Out:
# Outlier Detection for Numerical Features:

# %%
# Analyze FraudResult distribution
print("\nFraudResult Distribution:")
fraud_distribution = data['FraudResult'].value_counts(normalize=True) * 100
print(fraud_distribution)
# Out:
# FraudResult Distribution:
# FraudResult
# 0    99.798248
# 1     0.201752
# Name: proportion, dtype: float64

# %%
# TransactionStartTime analysis
data['TransactionStartTime'] = pd.to_datetime(data['TransactionStartTime'])
data['TransactionHour'] = data['TransactionStartTime'].dt.hour
data['TransactionDay'] = data['TransactionStartTime'].dt.day
data['TransactionMonth'] = data['TransactionStartTime'].dt.month
data['TransactionYear'] = data['TransactionStartTime'].dt.year

print("\nTransaction Hour Distribution:")
plt.figure(figsize=(10, 5))
sns.countplot(data=data, x='TransactionHour', palette='viridis')
plt.title("Transaction Hour Distribution")
plt.show()
# Out:
# Transaction Hour Distribution:
# C:\Users\Administrator.MMCY\AppData\Local\Temp\ipykernel_13196\496171879.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='TransactionHour', palette='viridis')
